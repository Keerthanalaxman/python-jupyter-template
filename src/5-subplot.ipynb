# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Data for plots
x = np.linspace(1, 10, 10)
y = x ** 2
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
scatter_x = [1, 2, 3, 4, 5]
scatter_y = [2, 4, 6, 8, 10]
pie_labels = ['Python', 'Java', 'C++', 'JavaScript']
pie_sizes = [40, 25, 20, 15]

# Create a 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Line Plot (Top-left)
axs[0, 0].plot(x, y, color='blue', linewidth=2, linestyle='-')
axs[0, 0].set_title('Line Chart')

# Bar Chart (Top-right)
axs[0, 1].bar(categories, values, color=['red', 'blue', 'green', 'purple'])
axs[0, 1].set_title('Bar Chart')

# Scatter Plot (Bottom-left)
axs[1, 0].scatter(scatter_x, scatter_y, color='black', marker='o')
axs[1, 0].set_title('Scatter Plot')

# Pie Chart (Bottom-right)
axs[1, 1].pie(pie_sizes, labels=pie_labels, autopct='%1.1f%%', startangle=140, colors=['blue', 'red', 'green', 'orange'])
axs[1, 1].set_title('Pie Chart')

# Adjust layout
plt.tight_layout()
plt.show()
